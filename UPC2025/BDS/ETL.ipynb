# %%
# install springer nature api if not installed
# !pip install springernature-api-client
# Out:
# Requirement already satisfied: springernature-api-client in /Users/russo/miniconda3/lib/python3.12/site-packages (0.0.3)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.0 in /Users/russo/miniconda3/lib/python3.12/site-packages (from springernature-api-client) (3.1.5)
# Requirement already satisfied: package-name<0.2,>=0.1 in /Users/russo/miniconda3/lib/python3.12/site-packages (from springernature-api-client) (0.1)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /Users/russo/miniconda3/lib/python3.12/site-packages (from springernature-api-client) (2.2.3)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/russo/miniconda3/lib/python3.12/site-packages (from springernature-api-client) (1.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/russo/miniconda3/lib/python3.12/site-packages (from springernature-api-client) (2.32.3)
# Requirement already satisfied: et-xmlfile in /Users/russo/miniconda3/lib/python3.12/site-packages (from openpyxl<4.0.0,>=3.1.0->springernature-api-client) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/russo/miniconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->springernature-api-client) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/russo/miniconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->springernature-api-client) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/russo/miniconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->springernature-api-client) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/russo/miniconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->springernature-api-client) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/russo/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->springernature-api-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/russo/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->springernature-api-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/russo/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->springernature-api-client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/russo/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->springernature-api-client) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/russo/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->springernature-api-client) (1.17.0)

# %% [raw]
# To use the Springer Open API ones needs first to request in the platform a personal API key.
#
# https://dev.springernature.com/docs/quick-start/api-access/
#
# Once granted, substitute accordingly in the apiKey variable below.

# %%
apiKey = 'your_API_key_granted_in_springernature_website'

# %%
import springernature_api_client.openaccess as openaccess
openaccess_client = openaccess.OpenAccessAPI(api_key = apiKey)

# %%
# build your query
query = "(keyword:NLP AND keyword:Transformer) OR (keyword:'Natural Language Processing' AND keyword:Transformer) AND type:{(Journal)} AND onlinedatefrom:2024-01-01 AND onlinedateto:2025-06-20"

result = openaccess_client.search(q=query, p=25, s=1, fetch_all=False, is_premium=False)

# %%
# Show results
print(f"Total number of results is {len(result['records'])} \n---")
for record in result['records']:
    print(f"Title: {record.get('title')}")
    print("---")
# Out:
# Total number of results is 25
# ---
# Title: The usage of a transformer based and artificial intelligence driven multidimensional feedback system in english writing instruction
# ---
# Title: Unleashing the transformers: NLP models detect AI writing in education
# ---
# Title: Transformers to the rescue: alleviating data scarcity in arabic grammatical error correction with pre-trained models
# ---
# Title: Emotion-Aware RoBERTa enhanced with emotion-specific attention and TF-IDF gating for fine-grained emotion recognition
# ---
# Title: Transformer-enhanced hierarchical encoding with multi-decoder for diversified MCQ distractor generation
# ---
# Title: Cross language transformation of free text into structured lobectomy surgical records from a multi center study
# ---
# Title: An LLM-based hybrid approach for enhanced automated essay scoring
# ---
# Title: Industrial applications of large language models
# ---
# Title: MISTIC: a novel approach for metastasis classification in Italian electronic health records using transformers
# ---
# Title: Comparison of active learning algorithms in classifying head computed tomography reports using bidirectional encoder representations from transformers
# ---
# Title: Impact of hospital-specific domain adaptation on BERT-based models to classify neuroradiology reports
# ---
# Title: BERT applications in natural language processing: a review
# ---
# Title: A neural network to identify requests, decisions, and arguments in court rulings on custody
# ---
# Title: The journey from natural language processing to large language models: key insights for radiologists
# ---
# Title: Uncertainty-aware automatic TNM staging classification for [^18F] Fluorodeoxyglucose PET-CT reports for lung cancer utilising transformer-based language models and multi-task learning
# ---
# Title: GPT-4 shows potential for identifying social anxiety from clinical interview data
# ---
# Title: A transformer-based approach to Nigerian Pidgin text generation
# ---
# Title: Uncovering suggestions in MOOC discussion forums: a transformer-based approach
# ---
# Title: How to Harness the Power of GPT for Scientific Research: A Comprehensive Review of Methodologies, Applications, and Ethical Considerations
# ---
# Title: Novel concept-based image captioning models using LSTM and multi-encoder transformer architecture
# ---
# Title: A transformer-based Urdu image caption generation
# ---
# Title: Robust Drug Use Detection on X: Ensemble Method with a Transformer Approach
# ---
# Title: From rule-based models to deep learning transformers architectures for natural language processing and sign language translation systems: survey, taxonomy and performance evaluation
# ---
# Title: VAIV bio-discovery service using transformer model and retrieval augmented generation
# ---
# Title: DiRecNetV2: A Transformer-Enhanced Network for Aerial Disaster Recognition
# ---

# %%
# Get ISSN or fall back to eISSN if ISSN is empty
for record in result['records']:
    print(f"Title: {record.get('title')}")
    issn = record.get('issn', '') or record.get('eIssn', '')
    record['key_issn'] = issn if issn else 'Not available'
    print(f"key_issn: {record['key_issn']}")
    print("---")
# Out:
# Title: The usage of a transformer based and artificial intelligence driven multidimensional feedback system in english writing instruction
# key_issn: 2045-2322
# ---
# Title: Unleashing the transformers: NLP models detect AI writing in education
# key_issn: 2197-9987
# ---
# Title: Transformers to the rescue: alleviating data scarcity in arabic grammatical error correction with pre-trained models
# key_issn: 0941-0643
# ---
# Title: Emotion-Aware RoBERTa enhanced with emotion-specific attention and TF-IDF gating for fine-grained emotion recognition
# key_issn: 2045-2322
# ---
# Title: Transformer-enhanced hierarchical encoding with multi-decoder for diversified MCQ distractor generation
# key_issn: 1573-7462
# ---
# Title: Cross language transformation of free text into structured lobectomy surgical records from a multi center study
# key_issn: 2045-2322
# ---
# Title: An LLM-based hybrid approach for enhanced automated essay scoring
# key_issn: 2045-2322
# ---
# Title: Industrial applications of large language models
# key_issn: 2045-2322
# ---
# Title: MISTIC: a novel approach for metastasis classification in Italian electronic health records using transformers
# key_issn: 1472-6947
# ---
# Title: Comparison of active learning algorithms in classifying head computed tomography reports using bidirectional encoder representations from transformers
# key_issn: 1861-6429
# ---
# Title: Impact of hospital-specific domain adaptation on BERT-based models to classify neuroradiology reports
# key_issn: 1432-1084
# ---
# Title: BERT applications in natural language processing: a review
# key_issn: 1573-7462
# ---
# Title: A neural network to identify requests, decisions, and arguments in court rulings on custody
# key_issn: 0924-8463
# ---
# Title: The journey from natural language processing to large language models: key insights for radiologists
# key_issn: 3004-8613
# ---
# Title: Uncertainty-aware automatic TNM staging classification for [^18F] Fluorodeoxyglucose PET-CT reports for lung cancer utilising transformer-based language models and multi-task learning
# key_issn: 1472-6947
# ---
# Title: GPT-4 shows potential for identifying social anxiety from clinical interview data
# key_issn: 2045-2322
# ---
# Title: A transformer-based approach to Nigerian Pidgin text generation
# key_issn: 1381-2416
# ---
# Title: Uncovering suggestions in MOOC discussion forums: a transformer-based approach
# key_issn: 1573-7462
# ---
# Title: How to Harness the Power of GPT for Scientific Research: A Comprehensive Review of Methodologies, Applications, and Ethical Considerations
# key_issn: 1869-3474
# ---
# Title: Novel concept-based image captioning models using LSTM and multi-encoder transformer architecture
# key_issn: 2045-2322
# ---
# Title: A transformer-based Urdu image caption generation
# key_issn: 1868-5137
# ---
# Title: Robust Drug Use Detection on X: Ensemble Method with a Transformer Approach
# key_issn: 2193-567X
# ---
# Title: From rule-based models to deep learning transformers architectures for natural language processing and sign language translation systems: survey, taxonomy and performance evaluation
# key_issn: 1573-7462
# ---
# Title: VAIV bio-discovery service using transformer model and retrieval augmented generation
# key_issn: 1471-2105
# ---
# Title: DiRecNetV2: A Transformer-Enhanced Network for Aerial Disaster Recognition
# key_issn: 2661-8907
# ---

# %% [raw]
# One can make a intermediary save here, just with the results of the API

# %%
import json

# Save to file
with open('bulkArticles.json', 'w') as f:
    json.dump(result, f)

# %% [raw]
# Augmentation of the Articles with h-index via Web Crawling
#
# https://www.scimagojr.com/

# %%
import json

# Read the bulk file of articles downloaded from the API
with open('bulkArticles.json', 'r') as f:
    data = json.load(f)

# %%
import requests
from bs4 import BeautifulSoup
import time
import re

def get_scimago_metrics(issn):
    """Get journal metrics from SCImago by following their search→profile workflow"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
        'Accept-Language': 'en-US,en;q=0.9'
    }
    
    try:
        # Step 1: Perform ISSN search
        search_url = f"https://www.scimagojr.com/journalsearch.php?q={issn}"
        response = requests.get(search_url, headers=headers, timeout=10)
        response.raise_for_status()
        
        # Check for CAPTCHA
        if "captcha" in response.text.lower():
            return {'error': 'CAPTCHA triggered - Try manual search first'}
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Step 2: Find the journal link in search results
        results_div = soup.find('div', class_='search_results')
        if not results_div:
            return {'error': 'No search results found'}
            
        journal_link = results_div.find('a', href=True)
        if not journal_link:
            return {'error': 'Journal link not found in results'}
        
        # Step 3: Follow to journal profile page
        journal_url = "https://www.scimagojr.com/" + journal_link['href']
        time.sleep(3)  # Be polite
        
        journal_response = requests.get(journal_url, headers=headers, timeout=10)
        journal_soup = BeautifulSoup(journal_response.text, 'html.parser')
        
        # Step 4: Extract metrics - UPDATED H-INDEX SELECTOR
        h_index_elements = journal_soup.find_all('p', class_='hindexnumber')
        h_index = h_index_elements[1].text.strip() if len(h_index_elements) > 1 else 'N/A'
        sjr = h_index_elements[0].text.strip() if len(h_index_elements) > 1 else 'N/A'
        
        return {
            'journal': journal_link.get_text(strip=True),
            'h_index': h_index,
            'sjr': sjr
        }
        
    except Exception as e:
        return {'error': f'SCImago processing failed: {str(e)}'}

def get_journal_metrics(issn):
    """Main function to get metrics for a journal ISSN"""
    # Clean ISSN format
    issn = re.sub(r'[^0-9X]', '', issn.upper())
    if len(issn) != 8:
        print(f"error: key_issn {issn} Invalid ISSN format (must be 8 characters)")
        return {'error': 'Invalid ISSN format (must be 8 characters)'}
    
    # Try SCImago first
    scimago_result = get_scimago_metrics(issn)
    if not scimago_result.get('error'):
        return {'source': 'SCImago', 'issn': issn, **scimago_result}

    print(f"error: Journal not found in SCImago, key_issn: {issn}")
    return {'error': 'Journal not found in SCImago', 'issn': issn}

# Augmenting the papers with their journals h-index
if __name__ == "__main__":
    
    # some issns for testing, use if needed
    """
    test_issns = [
        "2045-2322",  # Scientific Reports
        "2197-9987",  # Journal of Computers in Education
        "1234-5678"   # Invalid ISSN
    ]
    """
    
    for record in data['records']:
        print(f"Title: {record.get('title')}")

        # uncomment if key_issn was not addressed earlier, for us key_issn is issn that fallsback to eIssn when issn is not available
        #issn = record.get('issn', '') or record.get('eIssn', '')
        #record['key_issn'] = issn if issn else 'Not available'
        
        print(f"\nFetching metrics for ISSN/eISSN: {record['key_issn']}:")
        start_time = time.time()
        metrics = get_journal_metrics(record['key_issn'])
        h_index = metrics.get('h_index', 9999) if metrics else 9999
        print(f"h_index {h_index}")
        record['h_index'] = h_index
        print(f"Results took ({time.time()-start_time:.2f}s)")
        print("---")
        
        #print(metrics)
        time.sleep(5)  # Rate limiting
# Out:
# Title: The usage of a transformer based and artificial intelligence driven multidimensional feedback system in english writing instruction
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (3.46s)
# ---
# Title: Unleashing the transformers: NLP models detect AI writing in education
#
# Fetching metrics for ISSN/eISSN: 2197-9987:
# h_index 31
# Results took (3.39s)
# ---
# Title: Transformers to the rescue: alleviating data scarcity in arabic grammatical error correction with pre-trained models
#
# Fetching metrics for ISSN/eISSN: 0941-0643:
# h_index 146
# Results took (3.44s)
# ---
# Title: Emotion-Aware RoBERTa enhanced with emotion-specific attention and TF-IDF gating for fine-grained emotion recognition
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (3.44s)
# ---
# Title: Transformer-enhanced hierarchical encoding with multi-decoder for diversified MCQ distractor generation
#
# Fetching metrics for ISSN/eISSN: 1573-7462:
# h_index 138
# Results took (4.45s)
# ---
# Title: Cross language transformation of free text into structured lobectomy surgical records from a multi center study
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (5.07s)
# ---
# Title: An LLM-based hybrid approach for enhanced automated essay scoring
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (3.85s)
# ---
# Title: Industrial applications of large language models
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (3.41s)
# ---
# Title: MISTIC: a novel approach for metastasis classification in Italian electronic health records using transformers
#
# Fetching metrics for ISSN/eISSN: 1472-6947:
# h_index 107
# Results took (3.43s)
# ---
# Title: Comparison of active learning algorithms in classifying head computed tomography reports using bidirectional encoder representations from transformers
#
# Fetching metrics for ISSN/eISSN: 1861-6429:
# h_index 71
# Results took (3.41s)
# ---
# Title: Impact of hospital-specific domain adaptation on BERT-based models to classify neuroradiology reports
#
# Fetching metrics for ISSN/eISSN: 1432-1084:
# h_index 182
# Results took (3.42s)
# ---
# Title: BERT applications in natural language processing: a review
#
# Fetching metrics for ISSN/eISSN: 1573-7462:
# h_index 138
# Results took (3.47s)
# ---
# Title: A neural network to identify requests, decisions, and arguments in court rulings on custody
#
# Fetching metrics for ISSN/eISSN: 0924-8463:
# h_index 52
# Results took (3.41s)
# ---
# Title: The journey from natural language processing to large language models: key insights for radiologists
#
# Fetching metrics for ISSN/eISSN: 3004-8613:
# error: Journal not found in SCImago, key_issn: 30048613
# h_index 9999
# Results took (2.77s)
# ---
# Title: Uncertainty-aware automatic TNM staging classification for [^18F] Fluorodeoxyglucose PET-CT reports for lung cancer utilising transformer-based language models and multi-task learning
#
# Fetching metrics for ISSN/eISSN: 1472-6947:
# h_index 107
# Results took (3.42s)
# ---
# Title: GPT-4 shows potential for identifying social anxiety from clinical interview data
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (3.41s)
# ---
# Title: A transformer-based approach to Nigerian Pidgin text generation
#
# Fetching metrics for ISSN/eISSN: 1381-2416:
# h_index 43
# Results took (3.43s)
# ---
# Title: Uncovering suggestions in MOOC discussion forums: a transformer-based approach
#
# Fetching metrics for ISSN/eISSN: 1573-7462:
# h_index 138
# Results took (3.42s)
# ---
# Title: How to Harness the Power of GPT for Scientific Research: A Comprehensive Review of Methodologies, Applications, and Ethical Considerations
#
# Fetching metrics for ISSN/eISSN: 1869-3474:
# h_index 35
# Results took (3.45s)
# ---
# Title: Novel concept-based image captioning models using LSTM and multi-encoder transformer architecture
#
# Fetching metrics for ISSN/eISSN: 2045-2322:
# h_index 347
# Results took (3.40s)
# ---
# Title: A transformer-based Urdu image caption generation
#
# Fetching metrics for ISSN/eISSN: 1868-5137:
# h_index 86
# Results took (3.42s)
# ---
# Title: Robust Drug Use Detection on X: Ensemble Method with a Transformer Approach
#
# Fetching metrics for ISSN/eISSN: 2193-567X:
# h_index 81
# Results took (3.44s)
# ---
# Title: From rule-based models to deep learning transformers architectures for natural language processing and sign language translation systems: survey, taxonomy and performance evaluation
#
# Fetching metrics for ISSN/eISSN: 1573-7462:
# h_index 138
# Results took (3.42s)
# ---
# Title: VAIV bio-discovery service using transformer model and retrieval augmented generation
#
# Fetching metrics for ISSN/eISSN: 1471-2105:
# h_index 251
# Results took (3.41s)
# ---
# Title: DiRecNetV2: A Transformer-Enhanced Network for Aerial Disaster Recognition
#
# Fetching metrics for ISSN/eISSN: 2661-8907:
# h_index 49
# Results took (3.41s)
# ---

# %% [raw]
# Save the augmented results for further use

# %%
import json

# Save to file
with open('bulkArticlesAugmented.json', 'w') as f:
    json.dump(result, f)
